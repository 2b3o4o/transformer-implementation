# %%
import torch
print(torch)
print("Cuda Available:", torch.cuda.is_available())
print("Cuda Version:", torch.version.cuda)
# Out:
# <module 'torch' from 'c:\\Users\\lukew\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\torch\\__init__.py'>
# Cuda Available: True
# Cuda Version: 11.8

# %%
print(torch.cuda.is_available())  # Should return True if CUDA-enabled GPU is available
print(torch.cuda.current_device())  # Should return 0 as the first available GPU
print(torch.cuda.device_count())  # Number of available GPUs
print(torch.cuda.get_device_name(0))  # Name of the GPU device
# Out:
# True
# 0
# 1
# NVIDIA GeForce GTX 1060 with Max-Q Design
